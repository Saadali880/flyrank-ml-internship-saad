# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Saadali880/flyrank-ml-internship-saad/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose Lane 2: Refresh / Content Opportunity Scoring. I picked it because the starter repo's pipeline is already built around this exact question, producing a ranked review queue with reason codes, so I can validate the approach quickly and build on a proven baseline over the next 7 weeks.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# This lane answers which pages should be reviewed first for refresh, expansion, or monitoring. The decision this improves is which content a review team should look at first, given limited time. The action taken is a content reviewer opens the top ranked pages and decides whether to refresh, expand, protect, or leave them. The cost of a wrong recommendation is wasted reviewer time on a page that did not actually need attention, or a real declining page getting missed further down the queue.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset has 30,000 rows and 44 columns. Looking at the trend_direction column, 16,262 pages are currently declining, which is over half the dataset — far more than the 4,388 pages trending up. This shows there is strong, real demand for a refresh/opportunity scoring lane, since more than half the content has a declining signal worth reviewing over the next 7 weeks.

# %%
# !git clone https://github.com/Saadali880/flyrank-ml-internship-saad.git
# %cd flyrank-ml-internship-saad
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape)
print(df["trend_direction"].value_counts())
# Out:
# fatal: destination path 'flyrank-ml-internship-saad' already exists and is not an empty directory.
# /content/flyrank-ml-internship-saad
# (30000, 44)
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work can say which pages show signals associated with decline or opportunity, based on observed data such as impressions, clicks, position, and engagement. It is directional and decision-support only — it ranks pages worth reviewing first. It cannot prove that refreshing a page will cause it to recover, and it cannot claim to know Google's ranking algorithm, since that would require a real experiment, not this data alone.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
